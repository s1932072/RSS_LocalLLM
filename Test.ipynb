# %%
from langchain.chains.summarize import load_summarize_chain

import openai
from langchain.text_splitter import CharacterTextSplitter
from langchain.docstore.document import Document
from langchain.llms import OpenAI
from langchain.chains.summarize import load_summarize_chain
import time
from langchain.text_splitter import TokenTextSplitter

# %%
document = "心が通い合っている名コンビが暮れの大一番でドラマチックに復活を遂げました。まるで用意されたシナリオのようでした。ともに傷ついた人馬が役者の違いを見せつけ、中山競馬場につめかけた5万人を超えるファンの喝采を浴びました。\n「僕もドウデュースも帰ってきました。メンバーはそろっていましたが、ドウデュースが一番強いと信じていました。ラストの脚はいいものを持っているので、それに賭けていました。やっぱり競馬はいい。メリークリスマス！」\n有馬記念では最多33度目の騎乗。過去に1990年オグリキャップでの感動のラストランをはじめ、これで最多タイの4勝目となる。特にクリスマスイブにはめっぽう強く2006年ディープインパクト、2017年キタサンブラックに続いて今回で3度目となる。\n「帰ってきました」という冒頭のセリフは2013年、ケガの影響でスランプに陥っていた際にキズナで日本ダービーを制覇したときに語ったのと同じ。今回、ファンも待っていた決めゼリフでもあり、ユタカ・コールに応えるリップサービスでもあった。\nもはや“神”の域にある名手の技がさえた。\nレースは予想通りラストランとなるタイトルホルダー（牡5、栗田徹）が先行。前半1000メートルを60秒4とリズム良く逃げました。そして場内をどよめかせたのが、“死の枠”とされた8枠16番からスルスルと前に出たスターズオンアース(牝4、高柳)だ。クリストフ・ルメールが、好スタートから昨年の牝馬2冠王を2番手につける思い切りのいい先行策を取ったのである。\nだが、思った以上にペースが上がらない。すべてが武豊の想定内だった。武豊は、3枠5番から、ドウデュースを静かに出すと抜群のテクニックを発揮して序盤は折り合いに専念し、後方に構えて末脚を温存しました。\n1番人気に支持されたジャスティンパレス（牡4、杉山）はタイミングが合わずにスタートで出遅れて最後尾に回りました。本来ならば、もうひとつ前に持ち出したかったのだろうが、武豊が、そのポジションにいて抑え込みました。\nドウデュースは息を殺すかのように冷静に機をうかがいました。\n「道中は少し元気が良すぎるところがありましたが、我慢できました。残り700メートルぐらいからこの馬の末脚を引き出すことだけを考えて。4コーナーを回るときの脚が良かったので、なんとかなるかなと思っていました」\n3コーナー過ぎからロングスパートを仕掛けて4コーナーから内へ斜めに切れ込みました。距離のロスを最小限に抑えながら先頭集団を射程圏に捉え、スターズオンアースとタイトルホルダーに並び駆け、並んでからは、右ムチを入れ、ドウデュースの闘志を駆り立てました。そしてゴール寸前で2頭を差し切りました。\nジャスティンパレスも懸命に追いかけましたが4着に散りました。\n横山武史は「ドウデュースが相手だと思ってうまくマークはできたが、コーナーリングでギアが上がっていかず、ついて行けなかった」と肩を落としました。武豊の手綱がそれ以上のドウデュースの強烈なまくりの脚を導き出したということだろう。\n健闘したものの2着に終わったルメールは「枠は関係なかった。いいポジションが取れ、道中はマイペース。直線も頑張っていたが、最後で内へもたれた。その分の差」と敗者の弁。レース後は武豊と握手し互いの健闘を称え合いました。"

# split text
# 分割した文書に対して要約ができるように、元の文書を分割します。
text_splitter = CharacterTextSplitter(separator="。", chunk_size=100, chunk_overlap=50)
texts = text_splitter.split_text(document)
docs = [Document(page_content=t) for t in texts]

# %%
print(document_splits[2])
# Out:
# page_content='信じていました。ラストの脚はいいものを持っているので、それに賭けていました。やっぱり競馬はいい。メリークリスマス！」\n有馬記念では最多33度目の騎乗。過去に1990年オグリキャップでの感動のラストランをはじめ、これで最多タイの4勝目となる。特にクリスマスイブにはめっぽう強く2006年ディープインパクト、2017年キタサンブラックに続い'

# %%
template = """
次の文章を日本語で要約してください。

文章：
{text}

要約：
"""

PROMPT = PromptTemplate(
    input_variables=["text"],
    template=template,
)

# %%
chain = load_summarize_chain(llm,chain_type="map_reduce", map_prompt=PROMPT, combine_prompt=PROMPT, verbose=False)

# %%
result = chain.run(docs)
print(result)
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =      10.22 ms /    56 runs   (    0.18 ms per token,  5477.84 tokens per second)
# llama_print_timings: prompt eval time =    2063.84 ms /    42 tokens (   49.14 ms per token,    20.35 tokens per second)
# llama_print_timings:        eval time =    3163.51 ms /    55 runs   (   57.52 ms per token,    17.39 tokens per second)
# llama_print_timings:       total time =    5396.79 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =      16.52 ms /    91 runs   (    0.18 ms per token,  5508.14 tokens per second)
# llama_print_timings: prompt eval time =    3094.57 ms /    67 tokens (   46.19 ms per token,    21.65 tokens per second)
# llama_print_timings:        eval time =    5013.20 ms /    90 runs   (   55.70 ms per token,    17.95 tokens per second)
# llama_print_timings:       total time =    8384.05 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =       8.39 ms /    48 runs   (    0.17 ms per token,  5722.46 tokens per second)
# llama_print_timings: prompt eval time =    2685.20 ms /    58 tokens (   46.30 ms per token,    21.60 tokens per second)
# llama_print_timings:        eval time =    2593.61 ms /    47 runs   (   55.18 ms per token,    18.12 tokens per second)
# llama_print_timings:       total time =    5426.68 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# Llama.generate: prefix-match hit
# llama_print_timings:      sample time =       9.60 ms /    47 runs   (    0.20 ms per token,  4895.32 tokens per second)
# llama_print_timings: prompt eval time =    2157.21 ms /    47 tokens (   45.90 ms per token,    21.79 tokens per second)
# llama_print_timings:        eval time =    2533.56 ms /    46 runs   (   55.08 ms per token,    18.16 tokens per second)
# llama_print_timings:       total time =    4826.67 ms
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =       9.30 ms /    53 runs   (    0.18 ms per token,  5699.54 tokens per second)
# llama_print_timings: prompt eval time =    2941.16 ms /    63 tokens (   46.69 ms per token,    21.42 tokens per second)
# llama_print_timings:        eval time =    2854.87 ms /    52 runs   (   54.90 ms per token,    18.21 tokens per second)
# llama_print_timings:       total time =    5950.18 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =       3.20 ms /    20 runs   (    0.16 ms per token,  6251.95 tokens per second)
# llama_print_timings: prompt eval time =    2242.80 ms /    48 tokens (   46.73 ms per token,    21.40 tokens per second)
# llama_print_timings:        eval time =    1036.87 ms /    19 runs   (   54.57 ms per token,    18.32 tokens per second)
# llama_print_timings:       total time =    3339.84 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =       9.18 ms /    53 runs   (    0.17 ms per token,  5775.31 tokens per second)
# llama_print_timings: prompt eval time =    2452.92 ms /    52 tokens (   47.17 ms per token,    21.20 tokens per second)
# llama_print_timings:        eval time =    2867.41 ms /    52 runs   (   55.14 ms per token,    18.13 tokens per second)
# llama_print_timings:       total time =    5473.46 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =       6.62 ms /    39 runs   (    0.17 ms per token,  5895.69 tokens per second)
# Llama.generate: prefix-match hit
# llama_print_timings: prompt eval time =    2204.67 ms /    48 tokens (   45.93 ms per token,    21.77 tokens per second)
# llama_print_timings:        eval time =    2119.29 ms /    39 runs   (   54.34 ms per token,    18.40 tokens per second)
# llama_print_timings:       total time =    4436.82 ms
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =      10.85 ms /    62 runs   (    0.17 ms per token,  5715.34 tokens per second)
# llama_print_timings: prompt eval time =    3320.85 ms /    72 tokens (   46.12 ms per token,    21.68 tokens per second)
# llama_print_timings:        eval time =    3336.47 ms /    61 runs   (   54.70 ms per token,    18.28 tokens per second)
# llama_print_timings:       total time =    6839.98 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =      10.93 ms /    63 runs   (    0.17 ms per token,  5764.48 tokens per second)
# llama_print_timings: prompt eval time =    3411.31 ms /    74 tokens (   46.10 ms per token,    21.69 tokens per second)
# Llama.generate: prefix-match hit
# llama_print_timings:        eval time =    3466.90 ms /    62 runs   (   55.92 ms per token,    17.88 tokens per second)
# llama_print_timings:       total time =    7065.56 ms
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =       8.71 ms /    49 runs   (    0.18 ms per token,  5623.14 tokens per second)
# Llama.generate: prefix-match hit
# llama_print_timings: prompt eval time =    2899.89 ms /    63 tokens (   46.03 ms per token,    21.72 tokens per second)
# llama_print_timings:        eval time =    2742.47 ms /    48 runs   (   57.13 ms per token,    17.50 tokens per second)
# llama_print_timings:       total time =    5787.58 ms
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =       9.35 ms /    53 runs   (    0.18 ms per token,  5666.63 tokens per second)
# llama_print_timings: prompt eval time =    3583.29 ms /    77 tokens (   46.54 ms per token,    21.49 tokens per second)
# llama_print_timings:        eval time =    2884.65 ms /    52 runs   (   55.47 ms per token,    18.03 tokens per second)
# llama_print_timings:       total time =    6626.69 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =       3.89 ms /    21 runs   (    0.19 ms per token,  5398.46 tokens per second)
# llama_print_timings: prompt eval time =    1994.70 ms /    43 tokens (   46.39 ms per token,    21.56 tokens per second)
# llama_print_timings:        eval time =    1061.26 ms /    20 runs   (   53.06 ms per token,    18.85 tokens per second)
# llama_print_timings:       total time =    3119.64 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =       3.76 ms /    23 runs   (    0.16 ms per token,  6117.02 tokens per second)
# llama_print_timings: prompt eval time =    2594.12 ms /    56 tokens (   46.32 ms per token,    21.59 tokens per second)
# llama_print_timings:        eval time =    1167.48 ms /    22 runs   (   53.07 ms per token,    18.84 tokens per second)
# llama_print_timings:       total time =    3832.12 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =      11.60 ms /    63 runs   (    0.18 ms per token,  5430.10 tokens per second)
# llama_print_timings: prompt eval time =    3120.55 ms /    68 tokens (   45.89 ms per token,    21.79 tokens per second)
# Llama.generate: prefix-match hit
# llama_print_timings:        eval time =    3630.93 ms /    62 runs   (   58.56 ms per token,    17.08 tokens per second)
# llama_print_timings:       total time =    6940.11 ms
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =       9.60 ms /    50 runs   (    0.19 ms per token,  5207.79 tokens per second)
# llama_print_timings: prompt eval time =    2429.68 ms /    52 tokens (   46.72 ms per token,    21.40 tokens per second)
# llama_print_timings:        eval time =    2878.03 ms /    49 runs   (   58.74 ms per token,    17.03 tokens per second)
# llama_print_timings:       total time =    5457.07 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =       8.64 ms /    49 runs   (    0.18 ms per token,  5672.61 tokens per second)
# llama_print_timings: prompt eval time =    3282.26 ms /    70 tokens (   46.89 ms per token,    21.33 tokens per second)
# Llama.generate: prefix-match hit
# llama_print_timings:        eval time =    2757.81 ms /    48 runs   (   57.45 ms per token,    17.41 tokens per second)
# llama_print_timings:       total time =    6188.76 ms
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =       7.98 ms /    45 runs   (    0.18 ms per token,  5637.68 tokens per second)
# llama_print_timings: prompt eval time =    1937.32 ms /    40 tokens (   48.43 ms per token,    20.65 tokens per second)
# llama_print_timings:        eval time =    2524.45 ms /    44 runs   (   57.37 ms per token,    17.43 tokens per second)
# llama_print_timings:       total time =    4590.97 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =      10.43 ms /    52 runs   (    0.20 ms per token,  4986.10 tokens per second)
# llama_print_timings: prompt eval time =    2527.13 ms /    54 tokens (   46.80 ms per token,    21.37 tokens per second)
# llama_print_timings:        eval time =    3042.00 ms /    51 runs   (   59.65 ms per token,    16.77 tokens per second)
# llama_print_timings:       total time =    5723.67 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =      11.38 ms /    62 runs   (    0.18 ms per token,  5447.68 tokens per second)
# llama_print_timings: prompt eval time =    3164.94 ms /    67 tokens (   47.24 ms per token,    21.17 tokens per second)
# Llama.generate: prefix-match hit
# llama_print_timings:        eval time =    3656.69 ms /    61 runs   (   59.95 ms per token,    16.68 tokens per second)
# llama_print_timings:       total time =    7008.50 ms
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =       4.58 ms /    27 runs   (    0.17 ms per token,  5899.06 tokens per second)
# llama_print_timings: prompt eval time =    2981.02 ms /    62 tokens (   48.08 ms per token,    20.80 tokens per second)
# llama_print_timings:        eval time =    1449.20 ms /    26 runs   (   55.74 ms per token,    17.94 tokens per second)
# Llama.generate: prefix-match hit
# llama_print_timings:       total time =    4514.44 ms
#
# llama_print_timings:        load time =     462.49 ms
# llama_print_timings:      sample time =      10.28 ms /    57 runs   (    0.18 ms per token,  5545.29 tokens per second)
# llama_print_timings: prompt eval time =    2239.62 ms /    48 tokens (   46.66 ms per token,    21.43 tokens per second)
# llama_print_timings:        eval time =    3286.96 ms /    56 runs   (   58.70 ms per token,    17.04 tokens per second)
# llama_print_timings:       total time =    5692.97 ms
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 result = chain.run(docs)
#       2 print(result)
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/chains/base.py:507, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     505     if len(args) != 1:
#     506         raise ValueError("`run` supports only one positional argument.")
# --> 507     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     508         _output_key
#     509     ]
#     511 if kwargs and not args:
#     512     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     513         _output_key
#     514     ]
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/chains/base.py:312, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     310 except BaseException as e:
#     311     run_manager.on_chain_error(e)
# --> 312     raise e
#     313 run_manager.on_chain_end(outputs)
#     314 final_outputs: Dict[str, Any] = self.prep_outputs(
#     315     inputs, outputs, return_only_outputs
#     316 )
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/chains/base.py:306, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     299 run_manager = callback_manager.on_chain_start(
#     300     dumpd(self),
#     301     inputs,
#     302     name=run_name,
#     303 )
#     304 try:
#     305     outputs = (
# --> 306         self._call(inputs, run_manager=run_manager)
#     307         if new_arg_supported
#     308         else self._call(inputs)
#     309     )
#     310 except BaseException as e:
#     311     run_manager.on_chain_error(e)
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/chains/combine_documents/base.py:123, in BaseCombineDocumentsChain._call(self, inputs, run_manager)
#     121 # Other keys are assumed to be needed for LLM prediction
#     122 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 123 output, extra_return_dict = self.combine_docs(
#     124     docs, callbacks=_run_manager.get_child(), **other_keys
#     125 )
#     126 extra_return_dict[self.output_key] = output
#     127 return extra_return_dict
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/chains/combine_documents/map_reduce.py:236, in MapReduceDocumentsChain.combine_docs(self, docs, token_max, callbacks, **kwargs)
#     230 question_result_key = self.llm_chain.output_key
#     231 result_docs = [
#     232     Document(page_content=r[question_result_key], metadata=docs[i].metadata)
#     233     # This uses metadata from the docs, and the textual results from `results`
#     234     for i, r in enumerate(map_results)
#     235 ]
# --> 236 result, extra_return_dict = self.reduce_documents_chain.combine_docs(
#     237     result_docs, token_max=token_max, callbacks=callbacks, **kwargs
#     238 )
#     239 if self.return_intermediate_steps:
#     240     intermediate_steps = [r[question_result_key] for r in map_results]
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/chains/combine_documents/reduce.py:242, in ReduceDocumentsChain.combine_docs(self, docs, token_max, callbacks, **kwargs)
#     224 """Combine multiple documents recursively.
#     225
#     226 Args:
#    (...)
#     237     element returned is a dictionary of other keys to return.
#     238 """
#     239 result_docs, extra_return_dict = self._collapse(
#     240     docs, token_max=token_max, callbacks=callbacks, **kwargs
#     241 )
# --> 242 return self.combine_documents_chain.combine_docs(
#     243     docs=result_docs, callbacks=callbacks, **kwargs
#     244 )
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/chains/combine_documents/stuff.py:172, in StuffDocumentsChain.combine_docs(self, docs, callbacks, **kwargs)
#     170 inputs = self._get_inputs(docs, **kwargs)
#     171 # Call predict on the LLM.
# --> 172 return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/chains/llm.py:293, in LLMChain.predict(self, callbacks, **kwargs)
#     278 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     279     """Format prompt with kwargs and pass to LLM.
#     280
#     281     Args:
#    (...)
#     291             completion = llm.predict(adjective="funny")
#     292     """
# --> 293     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/chains/base.py:312, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     310 except BaseException as e:
#     311     run_manager.on_chain_error(e)
# --> 312     raise e
#     313 run_manager.on_chain_end(outputs)
#     314 final_outputs: Dict[str, Any] = self.prep_outputs(
#     315     inputs, outputs, return_only_outputs
#     316 )
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/chains/base.py:306, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     299 run_manager = callback_manager.on_chain_start(
#     300     dumpd(self),
#     301     inputs,
#     302     name=run_name,
#     303 )
#     304 try:
#     305     outputs = (
# --> 306         self._call(inputs, run_manager=run_manager)
#     307         if new_arg_supported
#     308         else self._call(inputs)
#     309     )
#     310 except BaseException as e:
#     311     run_manager.on_chain_error(e)
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/chains/llm.py:103, in LLMChain._call(self, inputs, run_manager)
#      98 def _call(
#      99     self,
#     100     inputs: Dict[str, Any],
#     101     run_manager: Optional[CallbackManagerForChainRun] = None,
#     102 ) -> Dict[str, str]:
# --> 103     response = self.generate([inputs], run_manager=run_manager)
#     104     return self.create_outputs(response)[0]
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/chains/llm.py:115, in LLMChain.generate(self, input_list, run_manager)
#     113 callbacks = run_manager.get_child() if run_manager else None
#     114 if isinstance(self.llm, BaseLanguageModel):
# --> 115     return self.llm.generate_prompt(
#     116         prompts,
#     117         stop,
#     118         callbacks=callbacks,
#     119         **self.llm_kwargs,
#     120     )
#     121 else:
#     122     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     123         cast(List, prompts), {"callbacks": callbacks}
#     124     )
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_core/language_models/llms.py:516, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     508 def generate_prompt(
#     509     self,
#     510     prompts: List[PromptValue],
#    (...)
#     513     **kwargs: Any,
#     514 ) -> LLMResult:
#     515     prompt_strings = [p.to_string() for p in prompts]
# --> 516     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_core/language_models/llms.py:666, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, **kwargs)
#     650         raise ValueError(
#     651             "Asked to cache, but no cache found at `langchain.cache`."
#     652         )
#     653     run_managers = [
#     654         callback_manager.on_llm_start(
#     655             dumpd(self),
#    (...)
#     664         )
#     665     ]
# --> 666     output = self._generate_helper(
#     667         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     668     )
#     669     return output
#     670 if len(missing_prompts) > 0:
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_core/language_models/llms.py:553, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     551     for run_manager in run_managers:
#     552         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 553     raise e
#     554 flattened_outputs = output.flatten()
#     555 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_core/language_models/llms.py:540, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     530 def _generate_helper(
#     531     self,
#     532     prompts: List[str],
#    (...)
#     536     **kwargs: Any,
#     537 ) -> LLMResult:
#     538     try:
#     539         output = (
# --> 540             self._generate(
#     541                 prompts,
#     542                 stop=stop,
#     543                 # TODO: support multiple run managers
#     544                 run_manager=run_managers[0] if run_managers else None,
#     545                 **kwargs,
#     546             )
#     547             if new_arg_supported
#     548             else self._generate(prompts, stop=stop)
#     549         )
#     550     except BaseException as e:
#     551         for run_manager in run_managers:
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_core/language_models/llms.py:1069, in LLM._generate(self, prompts, stop, run_manager, **kwargs)
#    1066 new_arg_supported = inspect.signature(self._call).parameters.get("run_manager")
#    1067 for prompt in prompts:
#    1068     text = (
# -> 1069         self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1070         if new_arg_supported
#    1071         else self._call(prompt, stop=stop, **kwargs)
#    1072     )
#    1073     generations.append([Generation(text=text)])
#    1074 return LLMResult(generations=generations)
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_community/llms/llamacpp.py:291, in LlamaCpp._call(self, prompt, stop, run_manager, **kwargs)
#     286 if self.streaming:
#     287     # If streaming is enabled, we use the stream
#     288     # method that yields as they are generated
#     289     # and return the combined strings from the first choices's text:
#     290     combined_text_output = ""
# --> 291     for chunk in self._stream(
#     292         prompt=prompt,
#     293         stop=stop,
#     294         run_manager=run_manager,
#     295         **kwargs,
#     296     ):
#     297         combined_text_output += chunk.text
#     298     return combined_text_output
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain_community/llms/llamacpp.py:344, in LlamaCpp._stream(self, prompt, stop, run_manager, **kwargs)
#     342 params = {**self._get_parameters(stop), **kwargs}
#     343 result = self.client(prompt=prompt, stream=True, **params)
# --> 344 for part in result:
#     345     logprobs = part["choices"][0].get("logprobs", None)
#     346     chunk = GenerationChunk(
#     347         text=part["choices"][0]["text"],
#     348         generation_info={"logprobs": logprobs},
#     349     )
#
# File ~/anaconda3/lib/python3.11/site-packages/llama_cpp/llama.py:1426, in Llama._create_completion(self, prompt, suffix, max_tokens, temperature, top_p, min_p, typical_p, logprobs, echo, stop, frequency_penalty, presence_penalty, repeat_penalty, top_k, stream, seed, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, stopping_criteria, logits_processor, grammar, logit_bias)
#    1423     self._ctx.reset_timings()
#    1425 if len(prompt_tokens) >= self._n_ctx:
# -> 1426     raise ValueError(
#    1427         f"Requested tokens ({len(prompt_tokens)}) exceed context window of {llama_cpp.llama_n_ctx(self.ctx)}"
#    1428     )
#    1430 if max_tokens is None or max_tokens <= 0:
#    1431     # Unlimited, depending on n_ctx.
#    1432     max_tokens = self._n_ctx - len(prompt_tokens)
#
# ValueError: Requested tokens (1131) exceed context window of 512
